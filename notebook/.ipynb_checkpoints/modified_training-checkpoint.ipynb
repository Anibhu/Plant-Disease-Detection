# %% [markdown]
# ## TEA PLANT DISEASE IDENTIFICATION

# %% [markdown]
# ### IMPORT REQUIRED LIBRARIES

# %%
import tensorflow as tf
# from tensorflow.keras import layers, models
import keras
from keras import layers
from keras import models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import os
import datetime
from sklearn.utils.class_weight import compute_class_weight
import pathlib

# %% [markdown]
# ### CONSTANTS

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS = 3
EPOCHS = 50
DATA_DIR = r"C:\Users\ANISH BHUIN\OneDrive\Desktop\jbooks\teaLeafBD"
MODEL_PATH = "tea_leaf_disease_model.keras"

# %% [markdown]
# ### LOAD DATASET

# %%
def load_dataset(data_dir):
    dataset = tf.keras.preprocessing.image_dataset_from_directory(
        data_dir,
        seed=123,
        shuffle=True,
        image_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=BATCH_SIZE
    )
    return dataset

dataset = load_dataset(DATA_DIR)
class_names = dataset.class_names
n_classes = len(class_names)

print(f"Found {len(dataset)*BATCH_SIZE} images belonging to {n_classes} classes.")
print("Class names:", class_names)
# Out:
# Found 5276 files belonging to 7 classes.
# Found 5280 images belonging to 7 classes.
# Class names: ['1. Tea algal leaf spot', '2. Brown Blight', '3. Gray Blight', '4. Helopeltis', '5. Red spider', '6. Green mirid bug', '7. Healthy leaf']

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# ### SPLIT,CATCH,SUFFLE AND PREFETCH THE DATA

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000, seed=42):
    assert (train_split + val_split + test_split) == 1.0, "Splits must add up to 1.0"
    
    # Calculate dataset size
    ds_size = tf.data.experimental.cardinality(ds).numpy()
    if ds_size == tf.data.INFINITE_CARDINALITY:
        raise ValueError("Dataset has infinite cardinality; cannot split.")
    elif ds_size == tf.data.UNKNOWN_CARDINALITY:
        raise ValueError("Dataset size is unknown; cannot split. Consider using a dataset where cardinality can be determined.")
    
    # Shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_size, seed=seed, reshuffle_each_iteration=False)

    # Compute sizes
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    # Split the dataset
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size + val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)
print(f"Train: {tf.data.experimental.cardinality(train_ds).numpy()}")
print(f"Val: {tf.data.experimental.cardinality(val_ds).numpy()}")
print(f"Test: {tf.data.experimental.cardinality(test_ds).numpy()}")
# Out:
# Train: 132
# Val: 16
# Test: 17

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(tf.data.AUTOTUNE)      # No shuffle
test_ds = test_ds.cache().prefetch(tf.data.AUTOTUNE)     # No shuffle

# %% [markdown]
# ### BUILDING THE MODEL

# %% [markdown]
# #### CREATING A LAYER FOR RESIZING AND NORMALIZATION

# %%
# from tensorflow.keras import layers
from keras import layers
from keras import models
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.Rescaling(1./255)
])

# %% [markdown]
# ### DATA AUGMENTATION

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.3),  # Increased rotation for leaf variations
    layers.RandomZoom(0.3),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(0.2),
])

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ### Using of Focal Loss

# %%
def sparse_focal_loss(gamma=2.0, alpha=0.25):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.int32)
        y_true = tf.one_hot(y_true, depth=tf.shape(y_pred)[-1])  # convert inside the loss
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)
        cross_entropy = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma)
        loss = weight * cross_entropy
        return tf.reduce_sum(loss, axis=1)
    return loss

# %% [markdown]
# ### Transfer Learning Model with MobileNetV2

# %%
def create_model():
    base_model = tf.keras.applications.MobileNetV2(
        input_shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS),
        include_top=False,
        weights='imagenet',
        pooling='avg'  # Using global average pooling directly
    )
    base_model.trainable = False  # Freeze base model initially

    inputs = tf.keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
    x = data_augmentation(inputs)
    x = tf.keras.applications.mobilenet_v2.preprocess_input(x)
    x = base_model(x)
    x = layers.Dropout(0.5)(x)  # Increased dropout for regularization
    outputs = layers.Dense(n_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    
    return model, base_model

model, base_model = create_model()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_1 (Sequential)            │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ true_divide (TrueDivide)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ subtract (Subtract)                  │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 1280)                │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 7)                   │           8,967 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,266,951 (8.65 MB)
#  Trainable params: 8,967 (35.03 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ### DEFINE CALLBACKS

# %%
def get_callbacks():
    return [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,  # Increased patience
            restore_best_weights=True,
            verbose=1
        ),
        tf.keras.callbacks.ModelCheckpoint(
            filepath = MODEL_PATH,
            monitor='val_accuracy',
            save_best_only=True,
            mode='max',
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=3,  # Adjusted patience
            min_lr=1e-6,
            verbose=1
        ),
        tf.keras.callbacks.TensorBoard(
            log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"),
            histogram_freq=1
        )
    ]

# %% [markdown]
# ### TRAIN THE MODEL

# %%
n_classes = 7

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=sparse_focal_loss(gamma=2.0, alpha=0.25),
    metrics=['accuracy']
)

# %%
# from sklearn.utils import class_weight
# import numpy as np

# # Get the labels from the dataset
# labels = []
# for _, label_batch in dataset:
#     labels.extend(label_batch.numpy())

# class_weights = class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.unique(labels),
#     y=labels
# )

# # Convert to dictionary format required by model.fit()
# class_weights_dict = {i: w for i, w in enumerate(class_weights)}

# %%
history = model.fit(
    train_ds.prefetch(tf.data.AUTOTUNE),
    validation_data=val_ds.prefetch(tf.data.AUTOTUNE),
    epochs=50,
    callbacks=get_callbacks(),
    # class_weight = class_weights_dict,
    verbose=1
)
# Out:
# Epoch 1/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 110s 760ms/step - accuracy: 0.1912 - loss: 0.4995 - val_accuracy: 0.2871 - val_loss: 0.3160 - learning_rate: 1.0000e-04
# Epoch 2/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 97s 731ms/step - accuracy: 0.2881 - loss: 0.3950 - val_accuracy: 0.3965 - val_loss: 0.2535 - learning_rate: 1.0000e-04
# Epoch 3/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 91s 691ms/step - accuracy: 0.3657 - loss: 0.3376 - val_accuracy: 0.5000 - val_loss: 0.2134 - learning_rate: 1.0000e-04
# Epoch 4/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 94s 714ms/step - accuracy: 0.4066 - loss: 0.3138 - val_accuracy: 0.5566 - val_loss: 0.1889 - learning_rate: 1.0000e-04
# Epoch 5/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 95s 717ms/step - accuracy: 0.4373 - loss: 0.2912 - val_accuracy: 0.5664 - val_loss: 0.1733 - learning_rate: 1.0000e-04
# Epoch 6/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 95s 715ms/step - accuracy: 0.4560 - loss: 0.2744 - val_accuracy: 0.6113 - val_loss: 0.1598 - learning_rate: 1.0000e-04
# Epoch 7/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 94s 710ms/step - accuracy: 0.4818 - loss: 0.2570 - val_accuracy: 0.6465 - val_loss: 0.1472 - learning_rate: 1.0000e-04
# Epoch 8/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 94s 714ms/step - accuracy: 0.4933 - loss: 0.2498 - val_accuracy: 0.6562 - val_loss: 0.1403 - learning_rate: 1.0000e-04
# Epoch 9/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 94s 713ms/step - accuracy: 0.5442 - loss: 0.2257 - val_accuracy: 0.6719 - val_loss: 0.1358 - learning_rate: 1.0000e-04
# Epoch 10/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 94s 711ms/step - accuracy: 0.5349 - loss: 0.2240 - val_accuracy: 0.6836 - val_loss: 0.1284 - learning_rate: 1.0000e-04
# Epoch 11/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 95s 716ms/step - accuracy: 0.5437 - loss: 0.2200 - val_accuracy: 0.6973 - val_loss: 0.1258 - learning_rate: 1.0000e-04
# Epoch 12/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 95s 718ms/step - accuracy: 0.5407 - loss: 0.2152 - val_accuracy: 0.7012 - val_loss: 0.1211 - learning_rate: 1.0000e-04
# Epoch 13/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 93s 706ms/step - accuracy: 0.5779 - loss: 0.2015 - val_accuracy: 0.7070 - val_loss: 0.1200 - learning_rate: 1.0000e-04
# Epoch 14/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 93s 705ms/step - accuracy: 0.5693 - loss: 0.1967 - val_accuracy: 0.7168 - val_loss: 0.1140 - learning_rate: 1.0000e-04
# Epoch 15/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 97s 736ms/step - accuracy: 0.5529 - loss: 0.1992 - val_accuracy: 0.7266 - val_loss: 0.1109 - learning_rate: 1.0000e-04
# Epoch 16/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 83s 631ms/step - accuracy: 0.5940 - loss: 0.1925 - val_accuracy: 0.7324 - val_loss: 0.1090 - learning_rate: 1.0000e-04
# Epoch 17/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 88s
# Epoch 40/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 87s 657ms/step - accuracy: 0.6327 - loss: 0.1495 - val_accuracy: 0.7539 - val_loss: 0.0929 - learning_rate: 2.0000e-05
# Epoch 41/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.6493 - loss: 0.1443
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 88s 666ms/step - accuracy: 0.6493 - loss: 0.1444 - val_accuracy: 0.7480 - val_loss: 0.0934 - learning_rate: 2.0000e-05
# Epoch 42/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 91s 685ms/step - accuracy: 0.6470 - loss: 0.1480 - val_accuracy: 0.7480 - val_loss: 0.0935 - learning_rate: 4.0000e-06
# Epoch 43/50
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 90s 683ms/step - accuracy: 0.6575 - loss: 0.1457 - val_accuracy: 0.7461 - val_loss: 0.0932 - learning_rate: 4.0000e-06
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 38.

# %% [markdown]
# ### Fine-Tuning Workflow

# %%
# 1. Unfreeze the base model (except first 120 layers)
base_model.trainable = True
for layer in base_model.layers[:120]:
    layer.trainable = False

# %%
# 2. Re-compile the model with a lower learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),  # Lower LR for fine-tuning
    loss=sparse_focal_loss(gamma=2.0, alpha=0.25),
    metrics=['accuracy']
)

# %%
# 3. Fit the model again with your callbacks
fine_tune_history = model.fit(
    train_ds.prefetch(tf.data.AUTOTUNE),
    validation_data=val_ds.prefetch(tf.data.AUTOTUNE),
    epochs=15,  # or whatever you want
    callbacks=get_callbacks(),
    # class_weight = class_weights_dict,
    verbose=1
)
# Out:
# Epoch 1/15
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 131s 909ms/step - accuracy: 0.6373 - loss: 0.1500 - val_accuracy: 0.7656 - val_loss: 0.0868 - learning_rate: 1.0000e-05
# Epoch 2/15
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 112s 844ms/step - accuracy: 0.6516 - loss: 0.1337 - val_accuracy: 0.7617 - val_loss: 0.0865 - learning_rate: 1.0000e-05
# Epoch 3/15
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 107s 812ms/step - accuracy: 0.6571 - loss: 0.1370 - val_accuracy: 0.7539 - val_loss: 0.0917 - learning_rate: 1.0000e-05
# Epoch 4/15
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 104s 788ms/step - accuracy: 0.6668 - loss: 0.1308 - val_accuracy: 0.7480 - val_loss: 0.0935 - learning_rate: 1.0000e-05
# Epoch 5/15
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.6878 - loss: 0.1168
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 105s 793ms/step - accuracy: 0.6877 - loss: 0.1168 - val_accuracy: 0.7383 - val_loss: 0.0974 - learning_rate: 1.0000e-05
# Epoch 6/15
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 104s 789ms/step - accuracy: 0.6922 - loss: 0.1243 - val_accuracy: 0.7363 - val_loss: 0.0978 - learning_rate: 2.0000e-06
# Epoch 7/15
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 105s 791ms/step - accuracy: 0.7100 - loss: 0.1159 - val_accuracy: 0.7383 - val_loss: 0.0982 - learning_rate: 2.0000e-06
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs_range = range(len(acc))
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def evaluate_model(test_ds):
    model = tf.keras.models.load_model(MODEL_PATH, custom_objects={'loss': sparse_focal_loss(alpha=0.25, gamma=2.0)})
    
    # Get true and predicted labels
    y_true = []
    y_pred = []
    y_prob = []
    
    for images, labels in test_ds:
        preds = model.predict(images, verbose=0)
        y_true.extend(labels.numpy())
        y_pred.extend(np.argmax(preds, axis=1))
        y_prob.extend(preds)
    
    # Classification Report
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
    
    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()
    
    return y_true, y_pred, y_prob

y_true, y_pred, y_prob = evaluate_model(test_ds)
# Out:
# Classification Report:
#                         precision    recall  f1-score   support
#
# 1. Tea algal leaf spot     0.4717    0.6250    0.5376        40
#        2. Brown Blight     0.5200    0.5909    0.5532        44
#         3. Gray Blight     0.7407    0.4255    0.5405        94
#          4. Helopeltis     0.6786    0.6667    0.6726        57
#          5. Red spider     0.5690    0.6471    0.6055        51
#     6. Green mirid bug     0.8333    0.8000    0.8163       150
#        7. Healthy leaf     0.7984    0.9537    0.8692       108
#
#               accuracy                         0.7077       544
#              macro avg     0.6588    0.6727    0.6564       544
#           weighted avg     0.7175    0.7077    0.7026       544

# %% [markdown]
# ### Enhanced Prediction Function with Grad-CAM

# %%
def predict_and_visualize(img_path, actual_label=None):
    # Load and preprocess image
    img = tf.keras.utils.load_img(img_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    img_array = tf.keras.utils.img_to_array(img)
    img_array_expanded = np.expand_dims(img_array, axis=0)
    img_array_preprocessed = tf.keras.applications.mobilenet_v2.preprocess_input(img_array_expanded)
    
    # Make prediction
    model = tf.keras.models.load_model(MODEL_PATH)
    predictions = model.predict(img_array_preprocessed)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * np.max(predictions[0]), 2)
    
    # Create visualization
    plt.figure(figsize=(12, 6))
    
    # Original image
    plt.subplot(1, 2, 1)
    plt.imshow(img_array.astype('uint8'))
    if actual_label:
        title = f"Actual: {actual_label}\nPredicted: {predicted_class}\nConfidence: {confidence}%"
    else:
        title = f"Predicted: {predicted_class}\nConfidence: {confidence}%"
    plt.title(title)
    plt.axis('off')
    
    # Class probabilities
    plt.subplot(1, 2, 2)
    sorted_indices = np.argsort(predictions[0])[::-1]
    sorted_classes = [class_names[i] for i in sorted_indices]
    sorted_probs = predictions[0][sorted_indices]
    
    colors = plt.cm.viridis(np.linspace(0, 1, len(sorted_classes)))
    bars = plt.barh(range(len(sorted_classes)), sorted_probs, color=colors)
    plt.yticks(range(len(sorted_classes)), sorted_classes)
    plt.xlabel('Probability')
    plt.title('Class Probabilities')
    plt.gca().invert_yaxis()
    
    for i, bar in enumerate(bars):
        width = bar.get_width()
        plt.text(width + 0.01, bar.get_y() + bar.get_height()/2,
                f'{width:.2%}',
                va='center', ha='left')
    
    plt.tight_layout()
    plt.show()
    
    return predicted_class, confidence

# %% [markdown]
# ### VISUALIZATION

# %%
def visualize_predictions_with_probs(test_ds, num_images=4):  # Fewer images since each takes more space
    plt.figure(figsize=(20, 5*num_images))
    for images, labels in test_ds.take(1):
        for i in range(min(num_images, len(images))):
            # Image subplot
            plt.subplot(num_images, 2, 2*i+1)
            plt.imshow(images[i].numpy().astype("uint8"))
            
            # Preprocess and predict
            img_array = images[i].numpy()
            img_array_expanded = np.expand_dims(img_array, axis=0)
            img_array_preprocessed = tf.keras.applications.mobilenet_v2.preprocess_input(img_array_expanded)
            predictions = model.predict(img_array_preprocessed)
            
            predicted_class = class_names[np.argmax(predictions[0])]
            confidence = round(100 * np.max(predictions[0]), 2)
            actual_class = class_names[labels[i]]
            
            plt.title(f"Actual: {actual_class}\nPredicted: {predicted_class}\nConfidence: {confidence}%")
            plt.axis("off")
            
            # Probabilities subplot
            plt.subplot(num_images, 2, 2*i+2)
            sorted_indices = np.argsort(predictions[0])[::-1]
            sorted_classes = [class_names[i] for i in sorted_indices]
            sorted_probs = predictions[0][sorted_indices]
            
            colors = plt.cm.viridis(np.linspace(0, 1, len(sorted_classes)))
            bars = plt.barh(range(len(sorted_classes)), sorted_probs, color=colors)
            plt.yticks(range(len(sorted_classes)), sorted_classes)
            plt.xlabel('Probability')
            plt.title('Class Probabilities')
            plt.gca().invert_yaxis()
            
            for j, bar in enumerate(bars):
                width = bar.get_width()
                plt.text(width + 0.01, bar.get_y() + bar.get_height()/2,
                        f'{width:.2%}',
                        va='center', ha='left')
    
    plt.tight_layout()
    plt.show()
